# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('boston.csv')
df=df.drop(columns='Unnamed: 0')


plt.rcParams['figure.figsize'] = (10,8)
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import *
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
y=df[['PRICE']]
X=df[['MedInc']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
pred_lr = lr.predict(X_test)
print ("\n--- 1 parameter Linear Regression MSE ---")
mse1 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse1)
# Out:
# (16512, 1) (4128, 1) (16512, 1) (4128, 1)
#
# --- 1 parameter Linear Regression MSE ---
# Mean Squared Error: 0.7214982234014606

# %%
y=df[['PRICE']]
X=df[['MedInc','AveRooms']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
pred_lr = lr.predict(X_test)
print ("\n--- 2 parameters Linear Regression MSE ---")
mse2 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse2)
# Out:
# (16512, 2) (4128, 2) (16512, 1) (4128, 1)
#
# --- 2 parameters Linear Regression MSE ---
# Mean Squared Error: 0.7101927490883555

# %%
y=df[['PRICE']]
X=df[['MedInc','AveRooms', 'HouseAge']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
pred_lr = lr.predict(X_test)
print ("\n--- 3 parameters Linear Regression MSE ---")
mse3 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse3)
# Out:
# (16512, 3) (4128, 3) (16512, 1) (4128, 1)
#
# --- 3 parameters Linear Regression MSE ---
# Mean Squared Error: 0.6672960022809671

# %%
y=df[['PRICE']]
X=df[['MedInc','AveRooms', 'HouseAge','AveOccup']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
pred_lr = lr.predict(X_test)
print ("\n--- 4 parameters Linear Regression MSE ---")
mse4 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse4)
# Out:
# (16512, 4) (4128, 4) (16512, 1) (4128, 1)
#
# --- 4 parameters Linear Regression MSE ---
# Mean Squared Error: 0.6656276112569712

# %%
y=df[['PRICE']]
X=df[['MedInc','AveRooms', 'HouseAge','AveOccup', 'Population']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
pred_lr = lr.predict(X_test)
print ("\n--- 4 parameters Linear Regression MSE ---")
mse5 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse5)
# Out:
# (16512, 5) (4128, 5) (16512, 1) (4128, 1)
#
# --- 4 parameters Linear Regression MSE ---
# Mean Squared Error: 0.6646551260561232

# %% [markdown]
# #iris 회귀#

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import pandas as pd
df=pd.read_csv('iris.data',header=None)
df.columns=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth','Class']
df=df.drop(columns=['Class'])
df
plt.rcParams['figure.figsize'] = (10,8)
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
y=df[['SepalLength']]
X=df[['PetalLength']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
pred_lr = lr.predict(X_test)
print ("\n--- 1 parameter Linear Regression MSE ---")
mse1 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse1)
# Out:
# (120, 1) (30, 1) (120, 1) (30, 1)
#
# --- 1 parameter Linear Regression MSE ---
# Mean Squared Error: 0.15096082024122665

# %%
y=df[['SepalLength']]
X=df[['PetalLength', 'PetalWidth']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
pred_lr = lr.predict(X_test)
print ("\n--- 2 parameters Linear Regression MSE ---")
mse2 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse2)
# Out:
# (120, 2) (30, 2) (120, 1) (30, 1)
#
# --- 2 parameters Linear Regression MSE ---
# Mean Squared Error: 0.14858643650117218

# %%
y=df[['SepalLength']]
X=df[['PetalLength']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
knr = KNeighborsRegressor()
knr.fit(X_train, y_train)
knr.score(X_test, y_test)
pred_lr = knr.predict(X_test)
print ("\n--- 1 parameter KNeighbors Regression MSE ---")
mse1 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse1)
# Out:
# (120, 1) (30, 1) (120, 1) (30, 1)
#
# --- 1 parameter KNeighbors Regression MSE ---
# Mean Squared Error: 0.19316000000000028

# %%
y=df[['SepalLength']]
X=df[['PetalLength', 'PetalWidth']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
knr = KNeighborsRegressor()
knr.fit(X_train, y_train)
knr.score(X_test, y_test)
pred_lr = knr.predict(X_test)
print ("\n--- 1 parameter KNeighbors Regression MSE ---")
mse2 = mean_squared_error(y_test, pred_lr)
print("Mean Squared Error:", mse2)
# Out:
# (120, 2) (30, 2) (120, 1) (30, 1)
#
# --- 1 parameter KNeighbors Regression MSE ---
# Mean Squared Error: 0.18117333333333344
